# %% [markdown]
# # Ames Housing Data

# %%
import os
import math
import statistics

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns

# %%
# %matplotlib inline

# %%
pd.set_option( 'display.max_columns', None )
sns.set( rc = { 'figure.figsize' : ( 24, 5 ) } )

# %% [markdown]
# #### Global Functions

# %%
def get_numerical_features( df ):
    return df.select_dtypes( include = [ 'int64', 'float64' ] ).columns

def get_categorical_features( df ):
    return df.select_dtypes( include = [ 'object' ] ).columns

def na_heatmap( df ):
    fig, ax = plt.subplots( figsize = ( 25, 5 ) )
    sns.heatmap( df.isnull(), yticklabels = False, cbar = False )
    
def get_facet_grid( df, feature_type ):
    if feature_type == 'numerical':
        facet_grid = pd.melt( df, value_vars = sorted( get_numerical_columns( df ) ) )
        grid_plot  = sns.FacetGrid( facet_grid, col = 'variable', col_wrap = 7, sharex = False, sharey = False)
        grid_plot  = grid_plot.map( sns.distplot, 'value' )
        
        return grid_plot
    
    elif feature_type == 'categorical':
        facet_grid = pd.melt( df, value_vars = sorted( get_categorical_columns( df ) ) )
        grid_plot  = sns.FacetGrid( facet_grid, col = 'variable', col_wrap = 7, sharex = False, sharey = False )
        grid_plot  = grid_plot.map( sns.countplot, 'value' )

        plt.xticks( rotation = 'vertical' )
        [ plt.setp( ax.get_xticklabels(), rotation = 60 ) for ax in grid_plot.axes.flat ]
        grid_plot.fig.tight_layout()
        
        return grid_plot
    
    else:
        print( 'Please specify "numerical" of "categorical"' )

# %% [markdown]
# #### Load Data

# %%
data_path = os.getcwd() + '\\..\\data\\ames_housing\\'
train_raw = pd.read_csv( data_path + 'train.csv' )
test_raw  = pd.read_csv( data_path + 'test.csv' )

train_X = train_raw.drop( [ 'SalePrice', 'Id' ], axis = 1 )
train_y = train_raw[ 'SalePrice' ]
test_X  = test_raw.drop( [ 'Id' ], axis = 1 )

# %% [markdown]
# #### Explore the Data

# %%
print( "Train: {} \nTest: {}".format( train_X.shape, test_X.shape ) )
# Out:
# Train: (1460, 79)
# Test: (1459, 79)

# %%
train_X.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %%
full_X = pd.concat( [train_X, test_X] )

# %%
get_facet_grid( full_X, 'numerical' )

# %% [markdown]
# ###### Data Representation
# - **Right Skewness (Outliers):** 1stFlrSF, BsmtUnfSF, GarageArea, GarLivArea, LotFrontage, TotalBsmtSF
# - **Count Data:** BedroomAbvGr, BsmtFullBath, BsmtHalfBath, Fireplaces, FullBath, GarageCars, KitchenAbvGr, MSSubClass, MoSold, OverallCond, OverallQual, TotRmsAbvGrd, YrSold
# - **Ranked Data:** BedroomAbvGr, BsmtFullBath, BsmtHalfBath, Fireplaces, FullBath, GarageCars, HalfBath, KitchenAbvGr, MSSubClass, OverallCond, OverallQual, TotalRmsAbvGrd
# - **Binary Data:** 2ndFlrSF (Has Second Floor), 3SsnPorch & EnclosedPorch & OpenProchSF & ScreenPorch (Has Porch), BsmtFinSF & BsmtFinSF2 (Has Basement), MasVnrArea, PoolArea (Has Pool), WoodDeckSF (Has Deck)
#
# ###### Notes
# - Features that involve above ground may be better ranked as a total over individually. Some features may have more bedrooms, but most of them are not above ground.
# - Create new feature for total number of bedrooms, and make this ranked
# - Create new feature for total number of bathrooms/half bathrooms, and make these ranked
# - Create new feature for total surface area of house

# %%
get_facet_grid( full_X, 'categorical' )
# Out:
# C:\Users\scott\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ###### Data Representation
# - **Ranked Data:** Alley, BldgType, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, BsmtQual, CentralAir, Condition1, Condition2, ExterCond, ExterQual, Fence, FireplaceQual, Foundation, Functional, GarageCond, GarageFinish, GarageQual, GarageType, HeatingQC, KitchenQual, LandContour, LandSlope, LotShape, MSZoning, MasVnrType, PavedDrive, PoolQC, SaleCondition, Street, Utilities

# %%
train_y = np.log1p( train_y )
sns.distplot( train_y, bins = 75 )

# %%
na_heatmap( train_X )

# %% [markdown]
# #### Data Preprocessing

# %%
# Convert to Ranked
def convert_to_ranked( df ):
    df[ 'BsmtCond'     ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'BsmtExposure' ].replace( { 'No' : 1, 'Mn' : 2, 'Av' : 3, 'Gd' : 4 }, inplace = True )
    df[ 'BsmtFinType1' ].replace( { 'Unf' : 1, 'LwQ' : 2, 'Rec' : 3, 'BLQ' : 4, 'ALQ' : 5, 'GLQ' : 6 }, inplace = True )
    df[ 'BsmtFinType2' ].replace( { 'Unf' : 1, 'LwQ' : 2, 'Rec' : 3, 'BLQ' : 4, 'ALQ' : 5, 'GLQ' : 6 }, inplace = True )
    df[ 'BsmtQual'     ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'ExterCond'    ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'ExterQual'    ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'FireplaceQu'  ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'Functional'   ].replace( { 'Sal' : 1, 'Sev' : 2, 'Maj2' : 3, 'Maj1' : 4, 'Mod' : 5, 'Min2' : 6, 'Min1' : 7, 'Typ' : 8 }, inplace = True )
    df[ 'GarageCond'   ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'GarageFinish' ].replace( { 'Unf' : 1, 'RFn' : 2, 'Fin' : 3 }, inplace = True )
    df[ 'GarageQual'   ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'HeatingQC'    ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'KitchenQual'  ].replace( { 'Po' : 1, 'Fa' : 2, 'TA' : 3, 'Gd' : 4, 'Ex' : 5 }, inplace = True )
    df[ 'LandSlope'    ].replace( { 'Sev' : 1, 'Mod' : 2, 'Gtl' : 3 }, inplace = True )
    df[ 'LandContour'  ].replace( { 'Low' : 1, 'HLS' : 2, 'Bnk' : 3, 'Lvl' : 4 }, inplace = True )
    df[ 'LotShape'     ].replace( { 'Reg' : 1, 'IR1' : 2, 'IR2' : 3, 'IR3' : 4 }, inplace = True )
    df[ 'Utilities'    ].replace( { 'ELO' : 1, 'NoSeWa' : 2, 'NoSewr' : 3, 'AllPub' : 4 }, inplace = True )

# %% [markdown]
# Alley, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, BsmtQual, CentralAir, Condition1, Condition2, ExterCond, ExterQual, Fence, FireplaceQual, Foundation, Functional, GarageCond, GarageFinish, GarageQual, GarageType, HeatingQC, KitchenQual, LandContour, LandSlope, LotShape, MSZoning, MasVnrType, PavedDrive, PoolQC, SaleCondition, Street, Utilities
