# %%
import pandas as pd

# %%
data = pd.read_csv( '.\\output\\blizzard_follower_friends.csv' )

# %%
data
# Out:
#           screen_name                                        description  \
# 0             lvb1lcs           Professional Shit Talker.  Hip Hop Head.
# 1       chavezNamaste                #fighter\r\n#YoTambienAmoaMiPlaneta
# 2       Ethan29822497                                                NaN
# 3     385i6I6Cg5aBizn                                                NaN
# 4       Logan96519605                                                NaN
# 5            MardinGh  *Mardin Hosseini*\r\nKourd boy (can speak Pers...
# 6       thomaslin0718                                             NM$L❤️
# 7            lilxanxd  a compilation of me bursting my feelings out t...
# 8     mQe6c5TZPU3h2jV                                                NaN
# 9       SeanDennis_YT                                                NaN
# 10     pangolin_pixel  Pixel Pangolin is about three things:\r\n1.) S...
# 11        SissyKin288                                                NaN
# ...
